# %%
# !pip install tweepy pandas numpy plotly tqdm
# Out:
# Collecting tweepy
#   Downloading tweepy-4.12.1-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (1.21.6)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (5.11.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (4.64.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /opt/conda/lib/python3.7/site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /opt/conda/lib/python3.7/site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (2022.5)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly) (8.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Installing collected packages: tweepy
# Successfully installed tweepy-4.12.1

# %%
import tweepy
import pandas as pd
import numpy as np
import time
import glob
import json                          
import plotly.graph_objects as go    
import tqdm
from tqdm import trange
from tqdm import tqdm
import datetime as dt
import requests

# %%
# the secure way of defining api keys
# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
# import os
# bearer_token = os.environ.get("BEARER_TOKEN")

# the bad way of doing things
# api_key = '<api_key>'  # add in your api key from your Twitter Developer Account here
# api_key_secret = '<api_key_secret>' # add in your api secret from Twitter Developer Account here
# bearer_token = '<bearer_token>'
# access_token = '<access_token>'
# access_token_secret = '<access_token_secret>'

client = tweepy.Client(bearer_token=bearer_token)

# News Categories:
news_outlets = '((url:"www.bloomberg.com") OR (url:"www.fortune.com") OR (url:"www.theguardian.com") OR (url:"www.npr.org") OR (url:"www.salon.com") OR  (url:"www.newsweek.com") OR (url:"www.politico.com") OR (url:"www.pbs.org") OR (url:"www.economist.com") OR (url:"www.nbc.com") OR (url:"www.abcnews.com") OR (url:"www.cbsnews.com") OR (url:"www.cnn.com") OR (url:"www.foxnews.com") OR (url:"www.sfchronicle.com"))'

# documentation: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query#build
query_params = {'query': news_outlets + ' -is:retweet',
           'tweet.fields': 'author_id,entities', 'max_results':100}

search_url = "https://api.twitter.com/2/tweets/search/recent"

def bearer_oauth(r):
    '''Construct an authentication header for the search service 
    '''
    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r


def connect_to_endpoint(url, params):
    '''Send the Twitter API a request to get back some data on the query you built.
    '''
    # this is called a GET request
    response = requests.get(url, auth=bearer_oauth, params=params)
    
    if response.status_code != 200:  # code 200 indicates OK
        raise Exception(response.status_code, response.text)
    return response.json()

response = connect_to_endpoint(search_url, query_params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25073/1585552654.py in <module>
#      70
#      71 for r in responses:
# ---> 72     add_to_table(r)
#      73
#      74 df = pd.DataFrame({'Link': [i[0] for i in table],
#
# /tmp/ipykernel_25073/1585552654.py in add_to_table(r)
#      66   for x in range(r['meta']['result_count']):
#      67     row=[]
# ---> 68     row += (export(((r)['data'])[x]))
#      69     table.append(row)
#      70
#
# /tmp/ipykernel_25073/1585552654.py in export(js)
#      37 def export (js):
#      38     if 'urls' in ((js)['entities']):
# ---> 39         return ['www.twitter.com/anyuser/status/' + str((js)['id']), ((js)['text']), process((js)['text']), (((((js)['entities'])['urls'])[0])['expanded_url'])]
#      40     else:
#      41         return ['www.twitter.com/anyuser/status/' + str((js)['id']), ((js)['text']), process((js)['text']), '']
#
# NameError: name 'process' is not defined

# %%
# Output an array given a search query:
def parse_response(res):
    if 'urls' in res['entities']:
        return ['www.twitter.com/anyuser/status/' + str(res['id']), res['text'], res['entities']['urls'][0]['expanded_url']]
    else:
        return ['www.twitter.com/anyuser/status/' + str(res['id']), res['text'], '']


# This is necessary because the API generates results in pages.
def paginate(r):
    token = r['meta']['next_token']
    new_params = query_params
    new_params.update({'pagination_token':token})
    return connect_to_endpoint(search_url, new_params)

responses = [response]

# We arbitrarily chose to use 10 pages of max length 100.
for i in range(10):
    responses.append(paginate(responses[i]))

# Save all the responses to a .csv file:
table = []
def add_to_table(res):
    for x in range(res['meta']['result_count']):
        row = []
        row += (parse_response(((res)['data'])[x]))
        table.append(row)

for r in responses:
    add_to_table(r)

df = pd.DataFrame({'Link': [i[0] for i in table], 
                   'Body': [i[1] for i in table],
                   'Article': [i[2] for i in table],
                   })
                   
df.to_csv('news_tweets.csv')

# %%
for r in responses:
    print(r)
    break
# Out:
# {'data': [{'edit_history_tweet_ids': ['1598183664541655043'], 'author_id': '1107773065', 'text': '#Ethiopia Peace Process Undermined as #Eritrea Forces Continue Attacking Civilians - Bloomberg https://t.co/4vIVOxw8Om', 'entities': {'hashtags': [{'start': 0, 'end': 9, 'tag': 'Ethiopia'}, {'start': 38, 'end': 46, 'tag': 'Eritrea'}], 'annotations': [{'start': 1, 'end': 8, 'probability': 0.9238, 'type': 'Place', 'normalized_text': 'Ethiopia'}, {'start': 39, 'end': 45, 'probability': 0.8514, 'type': 'Place', 'normalized_text': 'Eritrea'}, {'start': 85, 'end': 93, 'probability': 0.9528, 'type': 'Organization', 'normalized_text': 'Bloomberg'}], 'urls': [{'start': 95, 'end': 118, 'url': 'https://t.co/4vIVOxw8Om', 'expanded_url': 'https://www.bloomberg.com/news/articles/2022-11-30/ethiopia-peace-process-undermined-as-eritrea-forces-continue-attacking-civilians', 'display_url': 'bloomberg.com/news/articles/…', 'images': [{'url': 'https://pbs.twimg.com/news_img/1597891514213941248/JFgBrlPE?format=jpg&name=orig', 'width': 1200, 'height': 668}, {'url': 'https://pbs.twimg.com/news_img/1597891514213941248/JFgBrlPE?format=jpg&name=150x150', 'width': 150, 'height': 150}], 'status': 200, 'title': 'Ethiopia Peace Process Undermined as Eritrean Forces Continue Attacking Civilians', 'description': 'Efforts to restore peace in Ethiopia after two years of fighting between government and rebel forces are being undermined by Eritrea, whose troops continue to attack civilians across its southern border, according to people with knowledge of the situation.', 'unwound_url': 'https://www.bloomberg.com/news/articles/2022-11-30/ethiopia-peace-process-undermined-as-eritrea-forces-continue-attacking-civilians'}]}, 'id': '1598183664541655043'}, {'edit_history_tweet_ids': ['1598183648968069121'], 'entities': {'mentions': [{'start': 153, 'end': 161, 'username': 'CityLab', 'id': '331803536'}], 'urls': [{'start': 125, 'end': 148, 'url': 'https://t.co/D0OEj0TbqK', 'expanded_url': 'https://www.bloomberg.com/news/articles/2016-03-28/kyu-shirataki-train-station-in-hokkaido-japan-closes-after-student-graduates', 'display_url': 'bloomberg.com/news/articles/…', 'images': [{'url': 'https://pbs.twimg.com/news_img/1597930811667324931/CQzBADZ-?format=jpg&name=orig', 'width': 1200, 'height': 900}, {'url': 'https://pbs.twimg.com/news_img/1597930811667324931/CQzBADZ-?format=jpg&name=150x150', 'width': 150, 'height': 150}], 'status': 200, 'title': 'A Bittersweet Ending for a Japanese Train Station and Its Lone Passenger', 'description': 'On the island of Hokkaido, the Kyu-shirataki train station’s last remaining patron—a student—has graduated from high school.', 'unwound_url': 'https://www.bloomberg.com/news/articles/2016-03-28/kyu-shirataki-train-station-in-hokkaido-japan-closes-after-student-graduates'}]}, 'author_id': '107405712', 'text': 'On the island of Hokkaido, the Kyu-shirataki train station’s last remaining patron—a student—has graduated from high school. https://t.co/D0OEj0TbqK via @citylab', 'id': '1598183648968069121'}, {'edit_history_tweet_ids': ['1598183629867335680'], 'author_id': '14836655', 'text': "No. 2 Stanford's bounce back from losing to No. 1 South Carolina continued as the Cardinal won their fourth straight, setting them up for the bigger challenges ahead on their schedule. https://t.co/p2JbvIpGZn", 'id': '1598183629867335680', 'entities': {'annotations': [{'start': 6, 'end': 13, 'probability': 0.9266, 'type': 'Organization', 'normalized_text': 'Stanford'}, {'start': 50, 'end': 63, 'probability': 0.5473, 'type': 'Place', 'normalized_text': 'South Carolina'}, {'start': 82, 'end': 89, 'probability': 0.8136, 'type': 'Organization', 'normalized_text': 'Cardinal'}], 'urls': [{'start': 185, 'end': 208, 'url': 'https://t.co/p2JbvIpGZn', 'expanded_url': 'https://trib.al/Y0kM9vZ', 'display_url': 'trib.al/Y0kM9vZ', 'images': [{'url': 'https://pbs.twimg.com/news_img/1598183631444484096/rttlvn5u?format=jpg&name=orig', 'width': 2048, 'height': 1365}, {'url': 'https:/ ...

# %%
r['data']
# Out:
# [{'edit_history_tweet_ids': ['1598183664541655043'],
#   'author_id': '1107773065',
#   'text': '#Ethiopia Peace Process Undermined as #Eritrea Forces Continue Attacking Civilians - Bloomberg https://t.co/4vIVOxw8Om',
#   'entities': {'hashtags': [{'start': 0, 'end': 9, 'tag': 'Ethiopia'},
#     {'start': 38, 'end': 46, 'tag': 'Eritrea'}],
#    'annotations': [{'start': 1,
#      'end': 8,
#      'probability': 0.9238,
#      'type': 'Place',
#      'normalized_text': 'Ethiopia'},
#     {'start': 39,
#      'end': 45,
#      'probability': 0.8514,
#      'type': 'Place',
#      'normalized_text': 'Eritrea'},
#     {'start': 85,
#      'end': 93,
#      'probability': 0.9528,
#      'type': 'Organization',
#      'normalized_text': 'Bloomberg'}],
#    'urls': [{'start': 95,
#      'end': 118,
#      'url': 'https://t.co/4vIVOxw8Om',
#      'expanded_url': 'https://www.bloomberg.com/news/articles/2022-11-30/ethiopia-peace-process-undermined-as-eritrea-forces-continue-attacking-civilians',
#      'display_url': 'bloomberg.com/news/articles/…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597891514213941248/JFgBrlPE?format=jpg&name=orig',
#        'width': 1200,
#        'height': 668},
#       {'url': 'https://pbs.twimg.com/news_img/1597891514213941248/JFgBrlPE?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Ethiopia Peace Process Undermined as Eritrean Forces Continue Attacking Civilians',
#      'description': 'Efforts to restore peace in Ethiopia after two years of fighting between government and rebel forces are being undermined by Eritrea, whose troops continue to attack civilians across its southern border, according to people with knowledge of the situation.',
#      'unwound_url': 'https://www.bloomberg.com/news/articles/2022-11-30/ethiopia-peace-process-undermined-as-eritrea-forces-continue-attacking-civilians'}]},
#   'id': '1598183664541655043'},
#  {'edit_history_tweet_ids': ['1598183648968069121'],
#   'entities': {'mentions': [{'start': 153,
#      'end': 161,
#      'username': 'CityLab',
#      'id': '331803536'}],
#    'urls': [{'start': 125,
#      'end': 148,
#      'url': 'https://t.co/D0OEj0TbqK',
#      'expanded_url': 'https://www.bloomberg.com/news/articles/2016-03-28/kyu-shirataki-train-station-in-hokkaido-japan-closes-after-student-graduates',
#      'display_url': 'bloomberg.com/news/articles/…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597930811667324931/CQzBADZ-?format=jpg&name=orig',
#        'width': 1200,
#        'height': 900},
#       {'url': 'https://pbs.twimg.com/news_img/1597930811667324931/CQzBADZ-?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'A Bittersweet Ending for a Japanese Train Station and Its Lone Passenger',
#      'description': 'On the island of Hokkaido, the Kyu-shirataki train station’s last remaining patron—a student—has graduated from high school.',
#      'unwound_url': 'https://www.bloomberg.com/news/articles/2016-03-28/kyu-shirataki-train-station-in-hokkaido-japan-closes-after-student-graduates'}]},
#   'author_id': '107405712',
#   'text': 'On the island of Hokkaido, the Kyu-shirataki train station’s last remaining patron—a student—has graduated from high school. https://t.co/D0OEj0TbqK via @citylab',
#   'id': '1598183648968069121'},
#  {'edit_history_tweet_ids': ['1598183629867335680'],
#   'author_id': '14836655',
#   'text': "No. 2 Stanford's bounce back from losing to No. 1 South Carolina continued as the Cardinal won their fourth straight, setting them up for the bigger challenges ahead on their schedule. https://t.co/p2JbvIpGZn",
#   'id': '1598183629867335680',
#   'entities': {'annotations': [{'start': 6,
#      'end': 13,
#      'probability': 0.9266,
#      'type': 'Organization',
#      'normalized_text': 'Stanford'},
#     {'start': 50,
#      'end': 63,
#      'probability': 0.5473,
#      'type': 'Place',
#      'normalized_text': 'South Carolina'},
#     {'start': 82,
#      'end': 89,
#      'probability': 0.8136,
#      'type': 'Organization',
#      'normalized_text': 'Cardinal'}],
#    'urls': [{'start': 185,
#      'end': 208,
#      'url': 'https://t.co/p2JbvIpGZn',
#      'expanded_url': 'https://trib.al/Y0kM9vZ',
#      'display_url': 'trib.al/Y0kM9vZ',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598183631444484096/rttlvn5u?format=jpg&name=orig',
#        'width': 2048,
#        'height': 1365},
#       {'url': 'https://pbs.twimg.com/news_img/1598183631444484096/rttlvn5u?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Stanford women crush Santa Clara, win fourth straight to prepare for tough stretch',
#      'description': 'The Stanford women’s basketball team, ranked No. 2 in the country, continued its rebound...',
#      'unwound_url': 'https://www.sfchronicle.com/sports/college/article/Stanford-women-crush-Santa-Clara-win-fourth-17622955.php'}]}},
#  {'edit_history_tweet_ids': ['1598183628772888576'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 15,
#      'username': 'cliftonaduncan',
#      'id': '1219389106217783297'}],
#    'urls': [{'start': 88,
#      'end': 111,
#      'url': 'https://t.co/eMWBfHw2xi',
#      'expanded_url': 'https://www.theatlantic.com/video/index/590299/atomic-soldiers/',
#      'display_url': 'theatlantic.com/video/index/59…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597978940286828545/hhSWFJTl?format=jpg&name=orig',
#        'width': 854,
#        'height': 480},
#       {'url': 'https://pbs.twimg.com/news_img/1597978940286828545/hhSWFJTl?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Atomic Veterans Were Silenced for 50 Years. Now, They’re Talking.',
#      'description': 'Some of the last surviving soldiers exposed to nuclear-bomb tests share their unfathomable experiences.',
#      'unwound_url': 'https://www.theatlantic.com/video/index/590299/atomic-soldiers/'},
#     {'start': 113,
#      'end': 136,
#      'url': 'https://t.co/hu7hmrP30F',
#      'expanded_url': 'https://www.cbsnews.com/news/aids-drugs-tested-on-foster-kids/#app',
#      'display_url': 'cbsnews.com/news/aids-drug…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1595254886371033088/Sl8Xz5g7?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1595254886371033088/Sl8Xz5g7?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'AIDS Drugs Tested On Foster Kids',
#      'description': 'Researchers Tested Drugs On Kids Without Advocate Protection',
#      'unwound_url': 'https://www.cbsnews.com/news/aids-drugs-tested-on-foster-kids/#app'}]},
#   'author_id': '1519977343238000640',
#   'text': '@cliftonaduncan But you\'re a "radical extremist" if you don\'t trust the government.....\nhttps://t.co/eMWBfHw2xi\n\nhttps://t.co/hu7hmrP30F',
#   'id': '1598183628772888576'},
#  {'edit_history_tweet_ids': ['1598183625790738432'],
#   'author_id': '1337754019163496450',
#   'text': '#Birdflu #Animals ‘A possible extinction event’: the UK’s worst bird flu outbreak – podcast: The UK is in the middle of its worst outbreak of bird flu. The current strain of H5N1 avian influenza has devastated wild bird populations, killing thousands… https://t.co/Eesf5DJYl2',
#   'entities': {'hashtags': [{'start': 0, 'end': 8, 'tag': 'Birdflu'},
#     {'start': 9, 'end': 17, 'tag': 'Animals'}],
#    'urls': [{'start': 252,
#      'end': 275,
#      'url': 'https://t.co/Eesf5DJYl2',
#      'expanded_url': 'https://www.theguardian.com/science/audio/2022/dec/01/a-possible-extinction-event-the-uks-worst-bird-flu-outbreak-podcast?utm_source=dlvr.it&utm_medium=twitter',
#      'display_url': 'theguardian.com/science/audio/…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598181533864628229/qFZimioO?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598181533864628229/qFZimioO?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': '‘A possible extinction event’: the UK’s worst bird flu outbreak – podcast',
#      'description': 'The UK is in the middle of its worst outbreak of bird flu. To find out how both wild and captive bird populations are coping, Ian Sample speaks with Phoebe Weston, a biodiversity writer for the Guardian, and Paul Wigley, a professor in animal microbial ecosystems at the University of Bristol',
#      'unwound_url': 'https://www.theguardian.com/science/audio/2022/dec/01/a-possible-extinction-event-the-uks-worst-bird-flu-outbreak-podcast?utm_source=dlvr.it&utm_medium=twitter'}]},
#   'id': '1598183625790738432'},
#  {'edit_history_tweet_ids': ['1598183621969711105'],
#   'author_id': '16313592',
#   'text': 'New Jefferson County School start times announced, will change next fall https://t.co/G0fUjFBaBr https://t.co/BMYxrQ4Ie6',
#   'id': '1598183621969711105',
#   'entities': {'urls': [{'start': 73,
#      'end': 96,
#      'url': 'https://t.co/G0fUjFBaBr',
#      'expanded_url': 'https://www.cbsnews.com/colorado/news/new-jefferson-county-school-start-times-announced-will-change-next-fall/?utm_source=dlvr.it&utm_medium=twitter',
#      'display_url': 'cbsnews.com/colorado/news/…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598183623672606721/wGBHZiv1?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598183623672606721/wGBHZiv1?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'New Jefferson County School start times announced, will change next fall',
#      'description': "In Jefferson County, Colorado's largest school district is shifting start times for its nearly two hundred schools.",
#      'unwound_url': 'https://www.cbsnews.com/colorado/news/new-jefferson-county-school-start-times-announced-will-change-next-fall/?utm_source=dlvr.it&utm_medium=twitter'},
#     {'start': 97,
#      'end': 120,
#      'url': 'https://t.co/BMYxrQ4Ie6',
#      'expanded_url': 'https://twitter.com/CBSNewsColorado/status/1598183621969711105/photo/1',
#      'display_url': 'pic.twitter.com/BMYxrQ4Ie6',
#      'media_key': '3_1598183619910324224'}]}},
#  {'edit_history_tweet_ids': ['1598183612482203649'],
#   'author_id': '746330564760768513',
#   'text': 'Covid-19 origins: New studies agree that animals sold at Wuhan market are most likely what started pandemic | CNN https://t.co/qvSqTYhKep',
#   'id': '1598183612482203649',
#   'entities': {'annotations': [{'start': 0,
#      'end': 7,
#      'probability': 0.985,
#      'type': 'Other',
#      'normalized_text': 'Covid-19'},
#     {'start': 57,
#      'end': 61,
#      'probability': 0.4766,
#      'type': 'Other',
#      'normalized_text': 'Wuhan'},
#     {'start': 110,
#      'end': 112,
#      'probability': 0.9682,
#      'type': 'Organization',
#      'normalized_text': 'CNN'}],
#    'urls': [{'start': 114,
#      'end': 137,
#      'url': 'https://t.co/qvSqTYhKep',
#      'expanded_url': 'https://www.cnn.com/2022/07/26/health/wuhan-market-covid-19/index.html',
#      'display_url': 'cnn.com/2022/07/26/hea…',
#      'status': 200,
#      'title': 'New studies agree that animals sold at Wuhan market are most likely what started Covid-19 pandemic | CNN',
#      'description': 'In June, the World Health Organization recommended that scientists continue to research all possible origins of the Covid-19 pandemic, including a lab leak. Two newly published studies take totally different approaches but arrive at the same conclusion: The Huanan Seafood Market in Wuhan, China, was most likely the epicenter for the coronavirus.',
#      'unwound_url': 'https://www.cnn.com/2022/07/26/health/wuhan-market-covid-19/index.html'}]}},
#  {'edit_history_tweet_ids': ['1598183610917478400'],
#   'author_id': '16299627',
#   'text': 'The #Rangers\u200b beat the Senators on Wednesday night. https://t.co/k1wAqkWp2H',
#   'entities': {'hashtags': [{'start': 4, 'end': 12, 'tag': 'Rangers'}],
#    'annotations': [{'start': 5,
#      'end': 11,
#      'probability': 0.9649,
#      'type': 'Organization',
#      'normalized_text': 'Rangers'},
#     {'start': 21,
#      'end': 28,
#      'probability': 0.6629,
#      'type': 'Organization',
#      'normalized_text': 'e Senato'}],
#    'urls': [{'start': 52,
#      'end': 75,
#      'url': 'https://t.co/k1wAqkWp2H',
#      'expanded_url': 'https://cbsn.ws/3AVyxry',
#      'display_url': 'cbsn.ws/3AVyxry',
#      'status': 200,
#      'title': 'Vesey, Goodrow lead Rangers in win over Senators',
#      'description': 'Jaroslav Halak stopped 34 shots to get his first win with New York after starting 0-5-1 this season.',
#      'unwound_url': 'https://www.cbsnews.com/newyork/news/jimmy-vesey-barclay-goodrow-rangers-beat-senators/'}]},
#   'id': '1598183610917478400'},
#  {'edit_history_tweet_ids': ['1598183576633122816'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 12,
#      'username': 'CDCDirector',
#      'id': '426909329'}],
#    'urls': [{'start': 34,
#      'end': 57,
#      'url': 'https://t.co/PGZCQpkIuK',
#      'expanded_url': 'https://www.cbsnews.com/news/fauci-black-community-covid-19-vaccine/',
#      'display_url': 'cbsnews.com/news/fauci-bla…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598183579665649664/kkME0obm?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598183579665649664/kkME0obm?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Fauci urges Black community to be confident in COVID-19 vaccine: "The time is now to put skepticism aside"',
#      'description': '"I, myself, will be perfectly comfortable with taking the vaccine and I will recommend it for my family," said Fauci.',
#      'unwound_url': 'https://www.cbsnews.com/news/fauci-black-community-covid-19-vaccine/'}]},
#   'author_id': '1519113673645735943',
#   'text': '@CDCDirector You ALL are gross. \n\nhttps://t.co/PGZCQpkIuK \n\n"The terrible and shameful things that happened a long time ago are inexcusable," Fauci said Tuesday. "It would be doubly tragic that the lingering effects of that prevent you from doing something so important."\n\nSuch a sick freak.',
#   'id': '1598183576633122816'},
#  {'edit_history_tweet_ids': ['1598183574100135937'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 11,
#      'username': 'Mesnia1016',
#      'id': '1448309514499932161'},
#     {'start': 12, 'end': 17, 'username': 'Acyn', 'id': '16635277'}],
#    'urls': [{'start': 26,
#      'end': 49,
#      'url': 'https://t.co/NuuU4A0I3R',
#      'expanded_url': 'https://www.nbc.com/saturday-night-live/video/daily-affirmation/n10295',
#      'display_url': 'nbc.com/saturday-night…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598183577921155072/r8qHOPf2?format=jpg&name=orig',
#        'width': 640,
#        'height': 360},
#       {'url': 'https://pbs.twimg.com/news_img/1598183577921155072/r8qHOPf2?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Watch Saturday Night Live Highlight: Daily Affirmation - NBC.com',
#      'description': "Watch Saturday Night Live highlight 'Daily Affirmation' on NBC.com",
#      'unwound_url': 'https://www.nbc.com/saturday-night-live/video/daily-affirmation/n10295'}]},
#   'author_id': '133525097',
#   'text': '@Mesnia1016 @Acyn Smalley https://t.co/NuuU4A0I3R',
#   'id': '1598183574100135937'},
#  {'edit_history_tweet_ids': ['1598183570748866560'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 14,
#      'username': 'jack_be_lucky',
#      'id': '6799352'},
#     {'start': 15,
#      'end': 29,
#      'username': 'EggsWithRoses',
#      'id': '1259934598928019462'},
#     {'start': 30,
#      'end': 38,
#      'username': 'dantypo',
#      'id': '885883417342205956'}],
#    'urls': [{'start': 39,
#      'end': 62,
#      'url': 'https://t.co/yVr15JH9XE',
#      'expanded_url': 'https://www.foxnews.com/world/climate-protesters-accused-blood-their-hands-after-2-die-crash-amid-traffic-from-bridge-protest',
#      'display_url': 'foxnews.com/world/climate-…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598183573336764418/Zr0aUhqJ?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598183573336764418/Zr0aUhqJ?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': "Climate protesters accused of 'blood on their hands' after 2 die in crash amid traffic from bridge protest",
#      'description': 'Two climate protesters in England are being criticized for having "blood on their hands" after two people were killed in a traffic accident amid congestion from a protest.',
#      'unwound_url': 'https://www.foxnews.com/world/climate-protesters-accused-blood-their-hands-after-2-die-crash-amid-traffic-from-bridge-protest'}]},
#   'author_id': '1068020890858913794',
#   'text': '@jack_be_lucky @EggsWithRoses @dantypo https://t.co/yVr15JH9XE',
#   'id': '1598183570748866560'},
#  {'edit_history_tweet_ids': ['1598183551484465152'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 13,
#      'username': 'GlideSlope27',
#      'id': '202381113'}],
#    'urls': [{'start': 14,
#      'end': 37,
#      'url': 'https://t.co/7Kml4aa8DT',
#      'expanded_url': 'https://www.salon.com/2021/12/22/ghislaine-maxwell-trial-flew-on-epsteins-jets-more-often-than-previously-known_partner/',
#      'display_url': 'salon.com/2021/12/22/ghi…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597085275813216257/yFLRZYG2?format=jpg&name=orig',
#        'width': 1200,
#        'height': 810},
#       {'url': 'https://pbs.twimg.com/news_img/1597085275813216257/yFLRZYG2?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Ghislaine Maxwell trial: Trump flew on Epstein’s jets more often than previously known',
#      'description': 'Flight logs for Epstein\'s "Lolita Express" revealed by federal prosecutors in Ghislaine Maxwell\'s trial',
#      'unwound_url': 'https://www.salon.com/2021/12/22/ghislaine-maxwell-trial-flew-on-epsteins-jets-more-often-than-previously-known_partner/'}]},
#   'author_id': '1314765631867084800',
#   'text': '@GlideSlope27 https://t.co/7Kml4aa8DT',
#   'id': '1598183551484465152'},
#  {'edit_history_tweet_ids': ['1598183547055280130'],
#   'author_id': '1899275323',
#   'text': 'Extinction activist wants humans to voluntarily die out: ‘Feed ‘em, don’t breed ‘em’ https://t.co/HGPlxxzWD1 #FoxNews',
#   'entities': {'hashtags': [{'start': 109, 'end': 117, 'tag': 'FoxNews'}],
#    'urls': [{'start': 85,
#      'end': 108,
#      'url': 'https://t.co/HGPlxxzWD1',
#      'expanded_url': 'https://www.foxnews.com/media/extinction-activist-wants-humans-voluntarily-die-feed-em-breed-em',
#      'display_url': 'foxnews.com/media/extincti…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598121728173281280/GIFsumfh?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598121728173281280/GIFsumfh?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Extinction activist wants humans to voluntarily die out: ‘Feed ‘em, don’t breed ‘em’',
#      'description': 'Dr. Phil hosted a debate about whether the world was overpopulated with humans and on the ethics of procreation, especially when some people cannot afford to support them.',
#      'unwound_url': 'https://www.foxnews.com/media/extinction-activist-wants-humans-voluntarily-die-feed-em-breed-em'}]},
#   'id': '1598183547055280130'},
#  {'edit_history_tweet_ids': ['1598183544328626176'],
#   'author_id': '125632328',
#   'text': 'Georgia stops accepting applications from people asking for rent assistance https://t.co/92ED5UJukz #FoxNews',
#   'entities': {'hashtags': [{'start': 100, 'end': 108, 'tag': 'FoxNews'}],
#    'urls': [{'start': 76,
#      'end': 99,
#      'url': 'https://t.co/92ED5UJukz',
#      'expanded_url': 'https://www.foxnews.com/us/georgia-stops-accepting-applications-people-asking-rent-assistance',
#      'display_url': 'foxnews.com/us/georgia-sto…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598183545473671168/fmoSUv0P?format=png&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598183545473671168/fmoSUv0P?format=png&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Georgia stops accepting applications from people asking for rent assistance',
#      'description': 'A Georgia agency is no longer accepting applications for rent assistance from the federally funded aid program. The program began in 2020 to help combat evictions.',
#      'unwound_url': 'https://www.foxnews.com/us/georgia-stops-accepting-applications-people-asking-rent-assistance'}]},
#   'id': '1598183544328626176'},
#  {'edit_history_tweet_ids': ['1598183543288406016'],
#   'author_id': '449607055',
#   'text': 'England’s water: the world’s piggy bank. This just so wrong! “It’s water… and it should be managed in the interests of society and the environment.” https://t.co/fgtoCwu17c',
#   'id': '1598183543288406016',
#   'entities': {'urls': [{'start': 149,
#      'end': 172,
#      'url': 'https://t.co/fgtoCwu17c',
#      'expanded_url': 'https://www.theguardian.com/environment/ng-interactive/2022/nov/30/englands-water-the-worlds-piggy-bank?CMP=share_btn_tw',
#      'display_url': 'theguardian.com/environment/ng…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597962717926944769/GAd9Y0w9?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1597962717926944769/GAd9Y0w9?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'England’s water: the world’s piggy bank',
#      'description': 'England’s privatised water system is owned by funds, banks and billionaires across the world, as this country-by-country breakdown shows',
#      'unwound_url': 'https://www.theguardian.com/environment/ng-interactive/2022/nov/30/englands-water-the-worlds-piggy-bank?CMP=share_btn_tw'}]}},
#  {'edit_history_tweet_ids': ['1598183518441328640'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 11,
#      'username': 'reason_ter',
#      'id': '1248022899174322177'},
#     {'start': 12,
#      'end': 27,
#      'username': 'leo_brotherton',
#      'id': '1595010323395772418'}],
#    'urls': [{'start': 28,
#      'end': 51,
#      'url': 'https://t.co/7Kml4arbFT',
#      'expanded_url': 'https://www.salon.com/2021/12/22/ghislaine-maxwell-trial-flew-on-epsteins-jets-more-often-than-previously-known_partner/',
#      'display_url': 'salon.com/2021/12/22/ghi…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597085275813216257/yFLRZYG2?format=jpg&name=orig',
#        'width': 1200,
#        'height': 810},
#       {'url': 'https://pbs.twimg.com/news_img/1597085275813216257/yFLRZYG2?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Ghislaine Maxwell trial: Trump flew on Epstein’s jets more often than previously known',
#      'description': 'Flight logs for Epstein\'s "Lolita Express" revealed by federal prosecutors in Ghislaine Maxwell\'s trial',
#      'unwound_url': 'https://www.salon.com/2021/12/22/ghislaine-maxwell-trial-flew-on-epsteins-jets-more-often-than-previously-known_partner/'}]},
#   'author_id': '1314765631867084800',
#   'text': '@reason_ter @leo_brotherton https://t.co/7Kml4arbFT',
#   'id': '1598183518441328640'},
#  {'edit_history_tweet_ids': ['1598183507347447808'],
#   'author_id': '1514043867502284801',
#   'text': 'https://t.co/Aan2Z7oMiu',
#   'id': '1598183507347447808',
#   'entities': {'urls': [{'start': 0,
#      'end': 23,
#      'url': 'https://t.co/Aan2Z7oMiu',
#      'expanded_url': 'https://www.theguardian.com/us-news/2022/nov/30/jackson-water-crisis-us-justice-department-lawsuit',
#      'display_url': 'theguardian.com/us-news/2022/n…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598062701900861441/pGzuZqnF?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598062701900861441/pGzuZqnF?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'US justice department sues city of Jackson over water crisis',
#      'description': 'City and Mississippi health department sign order agreeing to federal oversight of the failing water system',
#      'unwound_url': 'https://www.theguardian.com/us-news/2022/nov/30/jackson-water-crisis-us-justice-department-lawsuit'}]}},
#  {'edit_history_tweet_ids': ['1598183481103699968'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 15,
#      'username': 'leo_brotherton',
#      'id': '1595010323395772418'}],
#    'urls': [{'start': 16,
#      'end': 39,
#      'url': 'https://t.co/7Kml4arbFT',
#      'expanded_url': 'https://www.salon.com/2021/12/22/ghislaine-maxwell-trial-flew-on-epsteins-jets-more-often-than-previously-known_partner/',
#      'display_url': 'salon.com/2021/12/22/ghi…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597085275813216257/yFLRZYG2?format=jpg&name=orig',
#        'width': 1200,
#        'height': 810},
#       {'url': 'https://pbs.twimg.com/news_img/1597085275813216257/yFLRZYG2?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Ghislaine Maxwell trial: Trump flew on Epstein’s jets more often than previously known',
#      'description': 'Flight logs for Epstein\'s "Lolita Express" revealed by federal prosecutors in Ghislaine Maxwell\'s trial',
#      'unwound_url': 'https://www.salon.com/2021/12/22/ghislaine-maxwell-trial-flew-on-epsteins-jets-more-often-than-previously-known_partner/'}]},
#   'author_id': '1314765631867084800',
#   'text': '@leo_brotherton https://t.co/7Kml4arbFT',
#   'id': '1598183481103699968'},
#  {'edit_history_tweet_ids': ['1598183451773251584'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 12,
#      'username': 'LFBBLibrary',
#      'id': '1492575669150269446'},
#     {'start': 13, 'end': 25, 'username': 'dylan_smity', 'id': '2760748781'}],
#    'urls': [{'start': 26,
#      'end': 49,
#      'url': 'https://t.co/Kxx5qg7jld',
#      'expanded_url': 'https://www.newsweek.com/when-it-comes-banning-books-both-right-left-are-guilty-opinion-1696045?amp=1',
#      'display_url': 'newsweek.com/when-it-comes-…',
#      'status': 200,
#      'title': 'When It Comes to Banning Books, Both Right and Left Are Guilty',
#      'description': 'The truth is, there is a moral panic on both sides when it comes to books.',
#      'unwound_url': 'https://www.newsweek.com/when-it-comes-banning-books-both-right-left-are-guilty-opinion-1696045?amp=1'}]},
#   'author_id': '1519099696622583810',
#   'text': '@LFBBLibrary @dylan_smity https://t.co/Kxx5qg7jld',
#   'id': '1598183451773251584'},
#  {'edit_history_tweet_ids': ['1598183431472562179'],
#   'author_id': '26130987',
#   'text': 'Scientists simulate ‘baby’ wormhole without rupturing space and time https://t.co/NrmTqsfi1O',
#   'id': '1598183431472562179',
#   'entities': {'urls': [{'start': 69,
#      'end': 92,
#      'url': 'https://t.co/NrmTqsfi1O',
#      'expanded_url': 'https://www.theguardian.com/science/2022/dec/01/scientists-simulate-baby-wormhole-without-rupturing-space-and-time?CMP=Share_iOSApp_Other',
#      'display_url': 'theguardian.com/science/2022/d…',
#      'status': 200,
#      'title': 'Scientists simulate ‘baby’ wormhole without rupturing space and time',
#      'description': 'Theoretical achievement hailed, though sending people through a physical wormhole remains in the realms of science fiction',
#      'unwound_url': 'https://www.theguardian.com/science/2022/dec/01/scientists-simulate-baby-wormhole-without-rupturing-space-and-time?CMP=Share_iOSApp_Other'}]}},
#  {'edit_history_tweet_ids': ['1598183423625289729'],
#   'entities': {'mentions': [{'start': 140,
#      'end': 151,
#      'username': 'googlenews',
#      'id': '33584794'}],
#    'hashtags': [{'start': 26, 'end': 41, 'tag': 'HerschelWalker'},
#     {'start': 81, 'end': 89, 'tag': 'Georgia'},
#     {'start': 92, 'end': 109, 'tag': 'WarnockforSenate'}],
#    'urls': [{'start': 111,
#      'end': 134,
#      'url': 'https://t.co/PDUtBJetVE',
#      'expanded_url': 'https://www.salon.com/2022/11/30/herschel-walker-repeatedly-said-i-live-in-texas-while-running-for-senate-in-georgia_partner/',
#      'display_url': 'salon.com/2022/11/30/her…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597991162991808513/lXu_iQnA?format=jpg&name=orig',
#        'width': 1200,
#        'height': 810},
#       {'url': 'https://pbs.twimg.com/news_img/1597991162991808513/lXu_iQnA?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Walker repeatedly said "I live in Texas" while running in Georgia',
#      'description': "Dems urge immediate investigation into Walker's residency and whether he lied about it to get onto the ballot.",
#      'unwound_url': 'https://www.salon.com/2022/11/30/herschel-walker-repeatedly-said-i-live-in-texas-while-running-for-senate-in-georgia_partner/'}]},
#   'author_id': '736433043481579520',
#   'text': 'Salon: "I live in Texas": #HerschelWalker repeatedly states he doesn\'t reside in #Georgia.\n\n#WarnockforSenate\n\nhttps://t.co/PDUtBJetVE\n\nvia @GoogleNews',
#   'id': '1598183423625289729'},
#  {'edit_history_tweet_ids': ['1598183418629566464'],
#   'entities': {'mentions': [{'start': 92,
#      'end': 101,
#      'username': 'politico',
#      'id': '9300262'}],
#    'urls': [{'start': 64,
#      'end': 87,
#      'url': 'https://t.co/nJi7snwxRG',
#      'expanded_url': 'https://politi.co/3gJncnK',
#      'display_url': 'politi.co/3gJncnK',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597028969341390848/7WRgcTZF?format=jpg&name=orig',
#        'width': 1200,
#        'height': 800},
#       {'url': 'https://pbs.twimg.com/news_img/1597028969341390848/7WRgcTZF?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': "The GOP's great Trump reckoning begins at the state party level",
#      'description': 'There are already recriminations. Whether they will amount to a course change remains unclear.',
#      'unwound_url': 'https://www.politico.com/news/2022/11/27/gops-trump-state-party-level-00070833'}]},
#   'author_id': '85779821',
#   'text': "The GOP's great Trump reckoning begins at the state party level https://t.co/nJi7snwxRG via @politico",
#   'id': '1598183418629566464'},
#  {'edit_history_tweet_ids': ['1598183397834489858'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 15,
#      'username': 'leo_brotherton',
#      'id': '1595010323395772418'}],
#    'urls': [{'start': 16,
#      'end': 39,
#      'url': 'https://t.co/jGMxuPH8Vj',
#      'expanded_url': 'https://www.newsweek.com/donald-trump-bill-clinton-prince-andrew-multiple-trips-jeffrey-epstein-plane-ghislaine-maxwell-1661513?amp=1',
#      'display_url': 'newsweek.com/donald-trump-b…',
#      'status': 200,
#      'title': "Trump, Clinton and Prince Andrew Took Multiple Trips on Epstein's Plane",
#      'description': 'The jury began deliberations in the trial of longtime Epstein associate Ghislaine Maxwell on Monday.',
#      'unwound_url': 'https://www.newsweek.com/donald-trump-bill-clinton-prince-andrew-multiple-trips-jeffrey-epstein-plane-ghislaine-maxwell-1661513?amp=1'}]},
#   'author_id': '1314765631867084800',
#   'text': '@leo_brotherton https://t.co/jGMxuPH8Vj',
#   'id': '1598183397834489858'},
#  {'edit_history_tweet_ids': ['1598183389752098816'],
#   'author_id': '283604227',
#   'text': 'Andy Vermaut shares:Jerry Stackhouse, Vanderbilt head coach, restrained from referees after fiery ejection: Jerry Stackhouse had to be held back and escorted off the floor after… https://t.co/SZVLVS3uVE Thank you. #ThankYouJournalistsForTheNewsWeGetFromYou #AndyVermautThanksYou https://t.co/x1s7eR1bZm',
#   'entities': {'hashtags': [{'start': 214,
#      'end': 256,
#      'tag': 'ThankYouJournalistsForTheNewsWeGetFromYou'},
#     {'start': 257, 'end': 278, 'tag': 'AndyVermautThanksYou'}],
#    'annotations': [{'start': 0,
#      'end': 11,
#      'probability': 0.5983,
#      'type': 'Person',
#      'normalized_text': 'Andy Vermaut'},
#     {'start': 20,
#      'end': 35,
#      'probability': 0.5657,
#      'type': 'Other',
#      'normalized_text': 'Jerry Stackhouse'},
#     {'start': 38,
#      'end': 47,
#      'probability': 0.857,
#      'type': 'Organization',
#      'normalized_text': 'Vanderbilt'},
#     {'start': 108,
#      'end': 123,
#      'probability': 0.5765,
#      'type': 'Person',
#      'normalized_text': 'Jerry Stackhouse'},
#     {'start': 258,
#      'end': 277,
#      'probability': 0.7227,
#      'type': 'Person',
#      'normalized_text': 'AndyVermautThanksYou'}],
#    'urls': [{'start': 179,
#      'end': 202,
#      'url': 'https://t.co/SZVLVS3uVE',
#      'expanded_url': 'https://www.foxnews.com/sports/jerry-stackhouse-vanderbilt-head-coach-restrained-referees-fiery-ejection?utm_source=dlvr.it&utm_medium=twitter',
#      'display_url': 'foxnews.com/sports/jerry-s…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598181479837831170/c65R7q8J?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598181479837831170/c65R7q8J?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Jerry Stackhouse, Vanderbilt head coach, restrained from referees after fiery ejection',
#      'description': "Jerry Stackhouse had to be held back and escorted off the floor after he was ejected and irate with refs in Vanderbilt's loss to VCU on Wednesday.",
#      'unwound_url': 'https://www.foxnews.com/sports/jerry-stackhouse-vanderbilt-head-coach-restrained-referees-fiery-ejection?utm_source=dlvr.it&utm_medium=twitter'},
#     {'start': 279,
#      'end': 302,
#      'url': 'https://t.co/x1s7eR1bZm',
#      'expanded_url': 'https://twitter.com/AndyVermaut/status/1598183389752098816/photo/1',
#      'display_url': 'pic.twitter.com/x1s7eR1bZm',
#      'media_key': '3_1598183387646545920'}]},
#   'id': '1598183389752098816'},
#  {'edit_history_tweet_ids': ['1598183386920943616'],
#   'author_id': '787546010',
#   'text': 'Jerry Stackhouse, Vanderbilt head coach, restrained from referees after fiery ejection https://t.co/S36ITeiNXD #news #topstories #worldnews',
#   'entities': {'hashtags': [{'start': 111, 'end': 116, 'tag': 'news'},
#     {'start': 117, 'end': 128, 'tag': 'topstories'},
#     {'start': 129, 'end': 139, 'tag': 'worldnews'}],
#    'urls': [{'start': 87,
#      'end': 110,
#      'url': 'https://t.co/S36ITeiNXD',
#      'expanded_url': 'http://dlvr.it/SdfMgH',
#      'display_url': 'dlvr.it/SdfMgH',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598181479837831170/c65R7q8J?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598181479837831170/c65R7q8J?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Jerry Stackhouse, Vanderbilt head coach, restrained from referees after fiery ejection',
#      'description': "Jerry Stackhouse had to be held back and escorted off the floor after he was ejected and irate with refs in Vanderbilt's loss to VCU on Wednesday.",
#      'unwound_url': 'https://www.foxnews.com/sports/jerry-stackhouse-vanderbilt-head-coach-restrained-referees-fiery-ejection?utm_source=dlvr.it&utm_medium=twitter'}]},
#   'id': '1598183386920943616'},
#  {'edit_history_tweet_ids': ['1598183384596901888'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 14,
#      'username': 'laurenboebert',
#      'id': '1201670995435646976'}],
#    'urls': [{'start': 90,
#      'end': 113,
#      'url': 'https://t.co/seL23jgby5',
#      'expanded_url': 'https://www.cbsnews.com/colorado/news/mandatory-recount-lauren-boebert-adam-frisch-colorado-congressional-district-3/',
#      'display_url': 'cbsnews.com/colorado/news/…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598111800784224256/Rd1Eyjc3?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598111800784224256/Rd1Eyjc3?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Mandatory recount ordered for Colorado Congressional District 3',
#      'description': "The Colorado Secretary of State's Office has ordered a mandatory recount of the results for the race of Colorado Congressional District 3.",
#      'unwound_url': 'https://www.cbsnews.com/colorado/news/mandatory-recount-lauren-boebert-adam-frisch-colorado-congressional-district-3/'}]},
#   'author_id': '842234299',
#   'text': '@laurenboebert CBS News: Mandatory recount ordered for Colorado Congressional District 3.\nhttps://t.co/seL23jgby5',
#   'id': '1598183384596901888'},
#  {'edit_history_tweet_ids': ['1598183382680469504'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 14,
#      'username': 'greenhousenyt',
#      'id': '268476335'}],
#    'hashtags': [{'start': 34, 'end': 48, 'tag': 'PaidSickLeave'},
#     {'start': 160, 'end': 168, 'tag': 'economy'},
#     {'start': 200, 'end': 211, 'tag': 'vaccinated'},
#     {'start': 261, 'end': 267, 'tag': 'Covid'}],
#    'annotations': [{'start': 22,
#      'end': 23,
#      'probability': 0.9756,
#      'type': 'Place',
#      'normalized_text': 'US'},
#     {'start': 262,
#      'end': 266,
#      'probability': 0.9334,
#      'type': 'Other',
#      'normalized_text': 'Covid'}],
#    'urls': [{'start': 276,
#      'end': 299,
#      'url': 'https://t.co/dn1s3LmjaX',
#      'expanded_url': 'https://www.newsweek.com/us-offers-employees-less-paid-leave-most-countries-1761219',
#      'display_url': 'newsweek.com/us-offers-empl…',
#      'status': 200,
#      'title': 'U.S. offers employees less paid leave than most countries around the world',
#      'description': 'United States is still the only developed country with no statutory paid leave, according to an analysis conducted by Resume.io.',
#      'unwound_url': 'https://www.newsweek.com/us-offers-employees-less-paid-leave-most-countries-1761219'}]},
#   'author_id': '1047950921173532673',
#   'text': "@greenhousenyt If the US required #PaidSickLeave for *ALL* workers like most developed countries, we wouldn't be on brink of a labor strike that could tank the #economy.\n\n(And more Americans would be #vaccinated &amp; wouldn't feel compelled to go to work with #Covid etc).\n.\nhttps://t.co/dn1s3LmjaX",
#   'id': '1598183382680469504'},
#  {'edit_history_tweet_ids': ['1598183381426397186'],
#   'author_id': '1462635917311549440',
#   'text': '"I tell you what," the president said. "No one’s ever done as much as president as this administration’s doing. Period." SO Expect Trudeau To Come Up with His Own version of this! https://t.co/CFDvSvtLiM',
#   'id': '1598183381426397186',
#   'entities': {'annotations': [{'start': 131,
#      'end': 137,
#      'probability': 0.9441,
#      'type': 'Person',
#      'normalized_text': 'Trudeau'}],
#    'urls': [{'start': 180,
#      'end': 203,
#      'url': 'https://t.co/CFDvSvtLiM',
#      'expanded_url': 'https://www.foxnews.com/politics/biden-appears-declare-himself-greatest-president-us-history',
#      'display_url': 'foxnews.com/politics/biden…',
#      'status': 200,
#      'title': 'Biden appears to declare himself the greatest president in US history',
#      'description': 'President Biden, while speaking at the Tribal Nations Summit at the Department of Interior on Wednesday, all but claimed to be the greatest president in U.S. history.',
#      'unwound_url': 'https://www.foxnews.com/politics/biden-appears-declare-himself-greatest-president-us-history'}]}},
#  {'edit_history_tweet_ids': ['1598183379429904384'],
#   'author_id': '787546010',
#   'text': "Lightning's Pat Maroon perfectly responds to fat-shaming comment from Bruins broadcaster Jack Edwards https://t.co/SA2D4YP7Xt #news #topstories #worldnews",
#   'entities': {'hashtags': [{'start': 126, 'end': 131, 'tag': 'news'},
#     {'start': 132, 'end': 143, 'tag': 'topstories'},
#     {'start': 144, 'end': 154, 'tag': 'worldnews'}],
#    'annotations': [{'start': 0,
#      'end': 8,
#      'probability': 0.8067,
#      'type': 'Organization',
#      'normalized_text': 'Lightning'},
#     {'start': 12,
#      'end': 21,
#      'probability': 0.9112,
#      'type': 'Person',
#      'normalized_text': 'Pat Maroon'},
#     {'start': 70,
#      'end': 75,
#      'probability': 0.9467,
#      'type': 'Organization',
#      'normalized_text': 'Bruins'},
#     {'start': 89,
#      'end': 100,
#      'probability': 0.9739,
#      'type': 'Person',
#      'normalized_text': 'Jack Edwards'}],
#    'urls': [{'start': 102,
#      'end': 125,
#      'url': 'https://t.co/SA2D4YP7Xt',
#      'expanded_url': 'http://dlvr.it/SdfMfx',
#      'display_url': 'dlvr.it/SdfMfx',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598181480731140098/621Z8Cf3?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598181480731140098/621Z8Cf3?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': "Lightning's Pat Maroon perfectly responds to fat-shaming comment from Bruins broadcaster Jack Edwards",
#      'description': "Bruins broadcaster Jack Edwards fat-shamed Tampa Bay Lightning forward Pat Maroon during the team's matchup on Tuesday night, to which the three-time Stanley Cup champion responded.",
#      'unwound_url': 'https://www.foxnews.com/sports/lightnings-pat-maroon-perfectly-responds-fat-shaming-comment-bruins-broadcaster-jack-edwards?utm_source=dlvr.it&utm_medium=twitter'}]},
#   'id': '1598183379429904384'},
#  {'edit_history_tweet_ids': ['1598183378058350592'],
#   'author_id': '283604227',
#   'text': "Andy Vermaut shares:Lightning's Pat Maroon perfectly responds to fat-shaming comment from Bruins broadcaster Jack Edwards: Bruins broadcaster Jack Edwards fat-shamed Tampa Bay… https://t.co/ao1lBEWIYR Thank you. #ThankYouJournalistsForTheNewsWeGetFromYou #AndyVermautThanksYou https://t.co/aMFuAfIQzJ",
#   'entities': {'hashtags': [{'start': 212,
#      'end': 254,
#      'tag': 'ThankYouJournalistsForTheNewsWeGetFromYou'},
#     {'start': 255, 'end': 276, 'tag': 'AndyVermautThanksYou'}],
#    'urls': [{'start': 177,
#      'end': 200,
#      'url': 'https://t.co/ao1lBEWIYR',
#      'expanded_url': 'https://www.foxnews.com/sports/lightnings-pat-maroon-perfectly-responds-fat-shaming-comment-bruins-broadcaster-jack-edwards?utm_source=dlvr.it&utm_medium=twitter',
#      'display_url': 'foxnews.com/sports/lightni…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598181480731140098/621Z8Cf3?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598181480731140098/621Z8Cf3?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': "Lightning's Pat Maroon perfectly responds to fat-shaming comment from Bruins broadcaster Jack Edwards",
#      'description': "Bruins broadcaster Jack Edwards fat-shamed Tampa Bay Lightning forward Pat Maroon during the team's matchup on Tuesday night, to which the three-time Stanley Cup champion responded.",
#      'unwound_url': 'https://www.foxnews.com/sports/lightnings-pat-maroon-perfectly-responds-fat-shaming-comment-bruins-broadcaster-jack-edwards?utm_source=dlvr.it&utm_medium=twitter'},
#     {'start': 277,
#      'end': 300,
#      'url': 'https://t.co/aMFuAfIQzJ',
#      'expanded_url': 'https://twitter.com/AndyVermaut/status/1598183378058350592/photo/1',
#      'display_url': 'pic.twitter.com/aMFuAfIQzJ',
#      'media_key': '3_1598183373096521728'}]},
#   'id': '1598183378058350592'},
#  {'edit_history_tweet_ids': ['1598183376531656704'],
#   'author_id': '57396415',
#   'text': 'Keski-ikäisyyteni näkyy siinä, että tämän tyyppisiä artikkeleja lukiessa jää miettimään miten käyttäjät saisi innostumaan järjen käyttämiseen rohkaisevista haasteista.\n https://t.co/pNaDs2QOD4',
#   'id': '1598183376531656704',
#   'entities': {'urls': [{'start': 169,
#      'end': 192,
#      'url': 'https://t.co/pNaDs2QOD4',
#      'expanded_url': 'https://www.theguardian.com/technology/2022/dec/01/tiktok-to-ban-videos-that-encourage-sunburn-and-tanning-after-alarm-from-medical-experts',
#      'display_url': 'theguardian.com/technology/202…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598146891568803848/xacVDIE6?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598146891568803848/xacVDIE6?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'TikTok to ban videos that encourage sunburn and tanning after alarm from medical experts',
#      'description': 'Medical experts had criticised video-sharing app for its popular #sunburnchallenge hashtag',
#      'unwound_url': 'https://www.theguardian.com/technology/2022/dec/01/tiktok-to-ban-videos-that-encourage-sunburn-and-tanning-after-alarm-from-medical-experts'}]}},
#  {'edit_history_tweet_ids': ['1598183370512826369'],
#   'author_id': '1337754019163496450',
#   'text': '#Globaleconomy #NewYork New York and Singapore top the list of world’s most expensive cities in 2022: Sydney sneaks into Top 10 as rising energy prices send inflation soaring globally, Economist Intelligence Unit survey finds\n\nNew York was the world’s… https://t.co/UZnuYKbgp6',
#   'entities': {'hashtags': [{'start': 0, 'end': 14, 'tag': 'Globaleconomy'},
#     {'start': 15, 'end': 23, 'tag': 'NewYork'}],
#    'annotations': [{'start': 24,
#      'end': 31,
#      'probability': 0.9797,
#      'type': 'Place',
#      'normalized_text': 'New York'},
#     {'start': 37,
#      'end': 45,
#      'probability': 0.9848,
#      'type': 'Place',
#      'normalized_text': 'Singapore'},
#     {'start': 102,
#      'end': 107,
#      'probability': 0.9726,
#      'type': 'Place',
#      'normalized_text': 'Sydney'},
#     {'start': 185,
#      'end': 211,
#      'probability': 0.4928,
#      'type': 'Other',
#      'normalized_text': 'Economist Intelligence Unit'},
#     {'start': 227,
#      'end': 234,
#      'probability': 0.9878,
#      'type': 'Place',
#      'normalized_text': 'New York'}],
#    'urls': [{'start': 253,
#      'end': 276,
#      'url': 'https://t.co/UZnuYKbgp6',
#      'expanded_url': 'https://www.theguardian.com/business/2022/dec/01/new-york-and-singapore-top-the-list-of-worlds-most-expensive-cities-in-2022?utm_source=dlvr.it&utm_medium=twitter',
#      'display_url': 'theguardian.com/business/2022/…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598180601261359105/xYeeK83m?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598180601261359105/xYeeK83m?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'New York and Singapore top the list of world’s most expensive cities in 2022',
#      'description': 'Sydney sneaks into Top 10 as rising energy prices send inflation soaring globally, Economist Intelligence Unit survey finds',
#      'unwound_url': 'https://www.theguardian.com/business/2022/dec/01/new-york-and-singapore-top-the-list-of-worlds-most-expensive-cities-in-2022?utm_source=dlvr.it&utm_medium=twitter'}]},
#   'id': '1598183370512826369'},
#  {'edit_history_tweet_ids': ['1598183370097582081'],
#   'author_id': '20582958',
#   'text': 'Tracking Australia’s progress on the climate crisis and the consequences of global heating https://t.co/rZnhlUKbqp',
#   'id': '1598183370097582081',
#   'entities': {'urls': [{'start': 91,
#      'end': 114,
#      'url': 'https://t.co/rZnhlUKbqp',
#      'expanded_url': 'https://www.theguardian.com/environment/datablog/ng-interactive/2022/oct/03/tracking-australias-progress-on-the-climate-crisis-and-the-consequences-of-global-heating?CMP=twt_a-environment_b-gdneco',
#      'display_url': 'theguardian.com/environment/da…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1576657162948210688/VNuQIOW2?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
# ...
#      'probability': 0.9542,
#      'type': 'Person',
#      'normalized_text': 'Lawrence Summers'},
#     {'start': 51,
#      'end': 57,
#      'probability': 0.9479,
#      'type': 'Other',
#      'normalized_text': 'Twitter'},
#     {'start': 64,
#      'end': 68,
#      'probability': 0.3483,
#      'type': 'Other',
#      'normalized_text': 'JOLTS'}],
#    'urls': [{'start': 204,
#      'end': 227,
#      'url': 'https://t.co/xygTITkz9S',
#      'expanded_url': 'https://trib.al/zzakQwt',
#      'display_url': 'trib.al/zzakQwt',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598175876990083075/wpGIFRAg?format=jpg&name=orig',
#        'width': 1200,
#        'height': 800},
#       {'url': 'https://pbs.twimg.com/news_img/1598175876990083075/wpGIFRAg?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Larry Summers Doubts Inflation Will Fall Much in This Job Market',
#      'description': 'Former Treasury Secretary Lawrence Summers says on Twitter the “JOLTS report shows a labor market that is cooling very slowly and will likely continue to be extraordinarily tight for some months to come.”',
#      'unwound_url': 'https://www.bloomberg.com/news/articles/2022-11-30/larry-summers-doubts-inflation-will-fall-much-in-this-job-market?utm_campaign=socialflow-organic&utm_medium=social&utm_source=twitter&utm_content=business&cmpid=socialflow-twitter-business'}]}},
#  {'edit_history_tweet_ids': ['1598182634076651520'],
#   'author_id': '62347531',
#   'text': 'The battle between online users and censors in China has gone into overdrive, forcing people to develop novel strategies to circumvent censorship https://t.co/58cE4qLtLs',
#   'id': '1598182634076651520',
#   'entities': {'annotations': [{'start': 47,
#      'end': 51,
#      'probability': 0.9684,
#      'type': 'Place',
#      'normalized_text': 'China'}],
#    'urls': [{'start': 146,
#      'end': 169,
#      'url': 'https://t.co/58cE4qLtLs',
#      'expanded_url': 'https://trib.al/xH02veL',
#      'display_url': 'trib.al/xH02veL',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1597034280449765376/UfMA3xwS?format=jpg&name=orig',
#        'width': 1200,
#        'height': 799},
#       {'url': 'https://pbs.twimg.com/news_img/1597034280449765376/UfMA3xwS?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Chinese Protesters Use Tricks to Evade Censors, Vent Covid Anger',
#      'description': '“Good good good good good good good good” may not seem like words written in anger, but in China this can be a serious public display of discontent.',
#      'unwound_url': 'https://www.bloomberg.com/news/articles/2022-11-27/chinese-protesters-use-tricks-to-evade-censors-vent-covid-anger?sref=PFCuwcPr&utm_medium=social&utm_source=twitter&utm_campaign=socialflow-organic&utm_content=business&cmpid=socialflow-twitter-business'}]}},
#  {'edit_history_tweet_ids': ['1598182634026311680'],
#   'author_id': '62347531',
#   'text': 'California may again reserve some of a limited financing resource for Fortress Investment Group’s passenger train to Las Vegas next year, a venture that failed to win over investors in 2020 https://t.co/r6pH9R7aQY',
#   'id': '1598182634026311680',
#   'entities': {'annotations': [{'start': 0,
#      'end': 9,
#      'probability': 0.9918,
#      'type': 'Place',
#      'normalized_text': 'California'},
#     {'start': 70,
#      'end': 94,
#      'probability': 0.7739,
#      'type': 'Organization',
#      'normalized_text': 'Fortress Investment Group'},
#     {'start': 117,
#      'end': 125,
#      'probability': 0.9875,
#      'type': 'Place',
#      'normalized_text': 'Las Vegas'}],
#    'urls': [{'start': 190,
#      'end': 213,
#      'url': 'https://t.co/r6pH9R7aQY',
#      'expanded_url': 'https://trib.al/bpTBscx',
#      'display_url': 'trib.al/bpTBscx',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598177635225550849/ANemFuyu?format=jpg&name=orig',
#        'width': 1200,
#        'height': 800},
#       {'url': 'https://pbs.twimg.com/news_img/1598177635225550849/ANemFuyu?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Fortress’s Brightline May Seek California Bonds for Las Vegas Train',
#      'description': 'California may again reserve some of a limited financing resource for Fortress Investment Group’s passenger train to Las Vegas next year, a venture that failed to win over investors in 2020.',
#      'unwound_url': 'https://www.bloomberg.com/news/articles/2022-11-30/fortress-las-vegas-rail-could-contend-for-california-cheap-debt?utm_medium=social&utm_source=twitter&utm_campaign=socialflow-organic&cmpid=socialflow-twitter-business&utm_content=business'}]}},
#  {'edit_history_tweet_ids': ['1598182628716331009'],
#   'author_id': '1367531',
#   'text': "Mickey Joseph, Nebraska's interim coach before Matt Rhule hire, arrested in domestic case https://t.co/W1f675Vwfs",
#   'id': '1598182628716331009',
#   'entities': {'annotations': [{'start': 0,
#      'end': 12,
#      'probability': 0.8732,
#      'type': 'Person',
#      'normalized_text': 'Mickey Joseph'},
#     {'start': 15,
#      'end': 22,
#      'probability': 0.6058,
#      'type': 'Place',
#      'normalized_text': 'Nebraska'},
#     {'start': 47,
#      'end': 56,
#      'probability': 0.8635,
#      'type': 'Person',
#      'normalized_text': 'Matt Rhule'}],
#    'urls': [{'start': 90,
#      'end': 113,
#      'url': 'https://t.co/W1f675Vwfs',
#      'expanded_url': 'https://fxn.ws/3H1MqbK',
#      'display_url': 'fxn.ws/3H1MqbK',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598182631283347459/iSbknjee?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598182631283347459/iSbknjee?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': "Mickey Joseph, Nebraska's interim coach before Matt Rhule hire, arrested in domestic case",
#      'description': 'Mickey Joseph, who was the interim head coach of Nebraska before they hired Matt Rhule, was arrested on Wednesday for strangulation and third-degree assault.',
#      'unwound_url': 'https://www.foxnews.com/sports/mickey-joseph-nebraskas-interim-coach-matt-rhule-hire-arrested-domestic-case?intcmp=tw_fnc'}]}},
#  {'edit_history_tweet_ids': ['1598182626745106432'],
#   'author_id': '34713362',
#   'text': 'Doctors and the Bank of England are identifying poor health as a major drag on the UK economy in comments aimed at putting the issue on the government’s agenda https://t.co/faofAiwBbR',
#   'id': '1598182626745106432',
#   'entities': {'annotations': [{'start': 16,
#      'end': 30,
#      'probability': 0.6116,
#      'type': 'Organization',
#      'normalized_text': 'Bank of England'},
#     {'start': 83,
#      'end': 84,
#      'probability': 0.873,
#      'type': 'Place',
#      'normalized_text': 'UK'}],
#    'urls': [{'start': 160,
#      'end': 183,
#      'url': 'https://t.co/faofAiwBbR',
#      'expanded_url': 'https://trib.al/MlOXv7x',
#      'display_url': 'trib.al/MlOXv7x',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598182628942831618/3cBSGnHc?format=jpg&name=orig',
#        'width': 1200,
#        'height': 799},
#       {'url': 'https://pbs.twimg.com/news_img/1598182628942831618/3cBSGnHc?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'UK Doctors Join BOE Saying Poor Health Is Hurting the Economy',
#      'description': 'Doctors and the Bank of England are identifying poor health as a major drag on the UK economy in comments aimed at putting the issue on the government’s agenda.',
#      'unwound_url': 'https://www.bloomberg.com/news/articles/2022-12-01/uk-doctors-join-boe-saying-poor-health-is-hurting-the-economy?cmpid=socialflow-twitter-business&utm_content=business&utm_campaign=socialflow-organic&utm_source=twitter&utm_medium=social'}]}},
#  {'edit_history_tweet_ids': ['1598182618981597184'],
#   'author_id': '1348152467494629376',
#   'text': 'https://t.co/fxWatrIZAk',
#   'id': '1598182618981597184',
#   'entities': {'urls': [{'start': 0,
#      'end': 23,
#      'url': 'https://t.co/fxWatrIZAk',
#      'expanded_url': 'https://www.economist.com/graphic-detail/2022/11/30/the-worlds-most-and-least-expensive-cities',
#      'display_url': 'economist.com/graphic-detail…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598078346512027657/KnB4PLoH?format=png&name=orig',
#        'width': 1280,
#        'height': 720},
#       {'url': 'https://pbs.twimg.com/news_img/1598078346512027657/KnB4PLoH?format=png&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'The world’s most, and least, expensive cities',
#      'description': 'Two share the top spot but prices are up almost everywhere',
#      'unwound_url': 'https://www.economist.com/graphic-detail/2022/11/30/the-worlds-most-and-least-expensive-cities'}]}},
#  {'edit_history_tweet_ids': ['1598182568352010242'],
#   'entities': {'mentions': [{'start': 114,
#      'end': 125,
#      'username': 'googlenews',
#      'id': '33584794'}],
#    'annotations': [{'start': 22,
#      'end': 25,
#      'probability': 0.7678,
#      'type': 'Person',
#      'normalized_text': 'Musk'},
#     {'start': 53,
#      'end': 57,
#      'probability': 0.9342,
#      'type': 'Organization',
#      'normalized_text': 'Apple'}],
#    'urls': [{'start': 85,
#      'end': 108,
#      'url': 'https://t.co/s7yq6HgbJk',
#      'expanded_url': 'https://www.politico.com/news/2022/11/30/musk-cook-twitter-apple-app-store-00071521',
#      'display_url': 'politico.com/news/2022/11/3…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598120968672649216/BESLMt7W?format=jpg&name=orig',
#        'width': 1200,
#        'height': 800},
#       {'url': 'https://pbs.twimg.com/news_img/1598120968672649216/BESLMt7W?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Never mind, Musk says — accusation against Apple was a ‘misunderstanding’',
#      'description': 'The billionaire writes that he and Apple CEO Tim Cook “resolved the misunderstanding about Twitter potentially being removed from the App Store.”',
#      'unwound_url': 'https://www.politico.com/news/2022/11/30/musk-cook-twitter-apple-app-store-00071521'}]},
#   'author_id': '1019181876710436867',
#   'text': 'POLITICO: Never mind, Musk says — accusation against Apple was a ‘misunderstanding’.\nhttps://t.co/s7yq6HgbJk\n\nvia @GoogleNews',
#   'id': '1598182568352010242'},
#  {'edit_history_tweet_ids': ['1598182567584288769'],
#   'author_id': '1524867466010107906',
#   'text': 'New York mayor plans to hospitalize mentally ill people involuntarily\n\nhttps://t.co/tn7WUApu1M',
#   'id': '1598182567584288769',
#   'entities': {'urls': [{'start': 71,
#      'end': 94,
#      'url': 'https://t.co/tn7WUApu1M',
#      'expanded_url': 'https://www.theguardian.com/us-news/2022/nov/30/nyc-eric-adams-involuntarily-hospitalize-mentally-ill-people',
#      'display_url': 'theguardian.com/us-news/2022/n…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598021305194123264/hmm6H7Ql?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598021305194123264/hmm6H7Ql?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'New York mayor plans to hospitalize mentally ill people involuntarily',
#      'description': 'Advocacy groups for civil rights groups and the homeless criticized mandate: ‘Mayor is playing fast and loose with the legal rights’',
#      'unwound_url': 'https://www.theguardian.com/us-news/2022/nov/30/nyc-eric-adams-involuntarily-hospitalize-mentally-ill-people'}]}},
#  {'edit_history_tweet_ids': ['1598182555911610368'],
#   'author_id': '107117835',
#   'text': 'On this day in history, Dec. 1, 1955, Rosa Parks refuses to give up her bus seat to a White passenger https://t.co/QDnN9i48TK',
#   'id': '1598182555911610368',
#   'entities': {'annotations': [{'start': 38,
#      'end': 47,
#      'probability': 0.9495,
#      'type': 'Person',
#      'normalized_text': 'Rosa Parks'}],
#    'urls': [{'start': 102,
#      'end': 125,
#      'url': 'https://t.co/QDnN9i48TK',
#      'expanded_url': 'https://fxn.ws/3OYkSFZ',
#      'display_url': 'fxn.ws/3OYkSFZ',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598182558017150976/46z5YN2U?format=jpg&name=orig',
#        'width': 1024,
#        'height': 512},
#       {'url': 'https://pbs.twimg.com/news_img/1598182558017150976/46z5YN2U?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'On this day in history, Dec. 1, 1955, Rosa Parks refuses to give up her bus seat to a White passenger',
#      'description': 'Rosa Parks, 42, ignited the Civil Rights Movement and the end of segregation in Alabama when she refused to give up her seat on a Montgomery bus on this day in history, Dec. 1, 1955.',
#      'unwound_url': 'https://www.foxnews.com/lifestyle/this-day-history-dec-1-1955-rosa-parks-refuses-give-bus-seat-white-passenger?intcmp=tw_life'}]}},
#  {'edit_history_tweet_ids': ['1598182548295004161'],
#   'author_id': '803673835820220417',
#   'text': 'US House approves bill to block rail strike and mandate paid sick leave - The Guardian US https://t.co/giKqab6Jm5 https://t.co/Ro9kAAh304',
#   'id': '1598182548295004161',
#   'entities': {'annotations': [{'start': 0,
#      'end': 7,
#      'probability': 0.5551,
#      'type': 'Place',
#      'normalized_text': 'US House'},
#     {'start': 74,
#      'end': 88,
#      'probability': 0.7671,
#      'type': 'Other',
#      'normalized_text': 'The Guardian US'}],
#    'urls': [{'start': 90,
#      'end': 113,
#      'url': 'https://t.co/giKqab6Jm5',
#      'expanded_url': 'http://dlvr.it/SdfMR8',
#      'display_url': 'dlvr.it/SdfMR8',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598108008600702977/VhVrv7bU?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598108008600702977/VhVrv7bU?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'US House approves bill to block rail strike and mandate paid sick leave',
#      'description': 'Lawmakers vote to impose tentative contract deal on a dozen unions as Bernie Sanders calls for sick-day amendment',
#      'unwound_url': 'https://www.theguardian.com/us-news/2022/nov/30/us-rail-strike-congress-house-senate-union-sick-leave'},
#     {'start': 114,
#      'end': 137,
#      'url': 'https://t.co/Ro9kAAh304',
#      'expanded_url': 'https://twitter.com/genuinebarbie2/status/1598182548295004161/photo/1',
#      'display_url': 'pic.twitter.com/Ro9kAAh304',
#      'media_key': '3_1598182546197852160'}]}},
#  {'edit_history_tweet_ids': ['1598182515982098433'],
#   'entities': {'mentions': [{'start': 0,
#      'end': 8,
#      'username': 'SDesh01',
#      'id': '1189881853676670982'},
#     {'start': 9, 'end': 20, 'username': 'ravishndtv', 'id': '47595335'}],
#    'urls': [{'start': 21,
#      'end': 44,
#      'url': 'https://t.co/irn4jijYq3',
#      'expanded_url': 'https://www.theguardian.com/world/2022/sep/19/indian-people-living-near-border-accuse-government-of-ceding-land-to-china',
#      'display_url': 'theguardian.com/world/2022/sep…',
#      'images': [{'url': 'https://pbs.twimg.com/news_img/1598182520079921158/o3rm927O?format=jpg&name=orig',
#        'width': 1200,
#        'height': 630},
#       {'url': 'https://pbs.twimg.com/news_img/1598182520079921158/o3rm927O?format=jpg&name=150x150',
#        'width': 150,
#        'height': 150}],
#      'status': 200,
#      'title': 'Indian government accused of ceding land in Himalayas to China',
#      'description': 'Locals claim ‘buffer zones’ have been established in areas previously under Indian control',
#      'unwound_url': 'https://www.theguardian.com/world/2022/sep/19/indian-people-living-near-border-accuse-government-of-ceding-land-to-china'}]},
#   'author_id': '1566457834774138881',
#   'text': '@SDesh01 @ravishndtv https://t.co/irn4jijYq3\nAsli Wala Surrender Kiya Ja Rha!',
#   'id': '1598182515982098433'}]
